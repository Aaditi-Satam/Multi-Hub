# %%
def budget_game_bot():

    #Budget game Bot

    print('Welcome to mobile store')

    #greet the user
    name=input('Enter your name : ')
    print('Hello', name, '!')

    #define the budget
    budget=int(input('Enter your budget : '))

    #specify the conditions
    if budget>=100000:
        print('Best brand would be Apple')
    elif budget>= 50000 and budget <= 100000:
        print('Best brand would be Samsung')
    elif budget>= 30000 and budget <= 50000:
        print('Best brand would be Redmi')
    elif budget>= 15000 and budget <= 30000:
        print('Best brand would be vivo')
    else:
        print('No phones available')
    print ('*'*40)    
        
        
def heads_and_tails_game_bot():
    
#welcome to heads and tails game

    print('Welcome to game of chance!')
    #take user input heads or tails
    user_input=input('Enter heads or tails : ')
    #displaying input given by user
    print('You chose: ', user_input.title())
    #tossing a coin(probability)
    import random
    if random.choice('ht')=='h':
        coin_toss='heads'
    else:
        coin_toss='tails'

    #displaying coin result
    print('Coin result is: ', coin_toss.title())

    #compare coin result and user input
    if user_input.lower()==coin_toss.lower():
        print('You win!')
    else:
        print('You lose!')
        
    print ('*'*40)
        
        
        

def dice_game():
    global times_win
    import random
#Dice Game

    #welcome user
    print('Welcome to the world of chance!')
    #user input
    user_input=int(input('Enter number of your choice : '))

    if user_input >0 or user_input <7:
        #display user input
        print('You have chosen : ', user_input)
        #rolling dice
        rolling_dice=int(random.choice('123456'))
        #display dice result
        print('Dice Result : ', rolling_dice)
        #compare
        if user_input==rolling_dice:
            print('You win!')
        else:
            print('You lose')
        print('*'*40)

        play_again=input('Do you want to play again?')
        if play_again.lower()=='yes':
            dice_game()
        else:
            import time
            time.sleep(5)
            print('Game Starting In : ')
            for i in range (9,0,-1):
                print(i,end='\r')
                time.sleep(1)
            dice_game()

    else: 
        print('Invalid Input!')
        print('Please enter number from 1-6')
        print('*'*40)
        dice_game()
    print ('*'*40)    
        
        
        
def tables():
    
    #take input from user
    n1=int(input('Enter number of your choice : '))

    for i in range(1,11):
        print(n1, 'x',i, '=', n1*i)    
    
    print ('*'*40)
    

def factorial():
    

    num=int(input('Enter a nuber of your choice : '))
    F=1
    for i in range(1, num+1):
        F=F*i
    print('Factorial of ', i, ':', F)
    
    print ('*'*40)



def fibonacci_sequence():
    
    #fibonacci 

    #take input from user

    user_input=int(input('Enter a number : '))
    n0= 0
    n1= 1
    for i in range(user_input):
        print(n0)
        n2=n0+n1
        n0=n1
        n1=n2
    
    print ('*'*40)
        
        
        
    
def cube():

#Cube

#take input from user
    number=int(input('Enter number of your choice : '))
    c=1
    for i in range(1, number+1):
        c=i**3
    print('Cube of', i,':', c)
    
    print ('*'*40)
            
            
        
        
def password_generator():
    
    import random
    
    num=int(input('Enter num of char for your password: '))
    if num >=8:

        for i in range(num):
            print(random.choice('abcdefghijklmnopqrstuvwxyzABCDEFGHIKLMNOPQRSTUVWXYZ1234567890!@#$%^&*())_+'),end='')
    else:
        print('minimum 8 characters required')
        
    print ('*'*40)
            
            
            
            
def list_of_party_students():

    #ask for name
    names=[]
    while True:
        op=int(input('1 new, 2 view, 3 remove, 4 exit'))
        if op==1:
            n=input('Enter your name : ')
            names.append(n)
        elif op==2:
            print(names)
        elif op==3:
            n=input('Enter your name : ')
            if n in names:
                names.remove(n)
            else:
                print('not registered')
        elif op==4:
            break
        else:
            print('Sorry i dont understand')
            
        print ('*'*40)
            
            

            
def voter_eligibility():
    
    age=int(input('Enter age : '))
    if (age<18) or (age>110):
        print('Invaid user')
    else:
        print('You can vote!')
        
    print ('*'*40)

# %%
import tkinter as tk

#main window
window=tk.Tk()

#window title
window.title('Python Project')

#size
window.geometry('500x500')

#label
tk.Label(window,text= 'PYTHON PROJECT',font=('Calibri',16)).place(x=170,y=30)
tk.Label(window,text= 'Made by : Aaditi Satam',font=('Calibri',12)).place(x=170,y=60)


#button
tk.Button(window,text='Budget Game',height=2,width=15,command=budget_game_bot).place(x=30,y=125)
tk.Button(window,text='Heads & Tails',height=2,width=15,command=heads_and_tails_game_bot).place(x=190,y=125)
tk.Button(window,text='Dice Game',height=2,width=15,command=dice_game).place(x=350,y=125)
tk.Button(window,text='Tables',height=2, width=15,command=tables).place(x=30,y=225)
tk.Button(window,text='Factorial ',height=2,width=15,command=factorial).place(x=190,y=225)
tk.Button(window,text='Fibonacci Sequence',height=2,width=15,command=fibonacci_sequence).place(x=350,y=225)
tk.Button(window,text='Cube',height=2,width=15,command=cube).place(x=30,y=325)
tk.Button(window,text='Password Generator',height=2,width=15,command=password_generator).place(x=190,y=325)
tk.Button(window,text='Party List Generator',height=2,width=15,command=list_of_party_students).place(x=350,y=325)
tk.Button(window,text='Voter ELigibility',height=2,width=15,command=voter_eligibility).place(x=190,y=425)

#for window display
window.mainloop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 18
#      14 tk.Label(window,text= 'Made by : Aaditi Satam',font=('Calibri',12)).place(x=170,y=60)
#      17 #button
# ---> 18 tk.Button(window,text='Budget Game',height=2,width=15,command=budget_game_bot).place(x=30,y=125)
#      19 tk.Button(window,text='Heads & Tails',height=2,width=15,command=heads_and_tails_game_bot).place(x=190,y=125)
#      20 tk.Button(window,text='Dice Game',height=2,width=15,command=dice_game).place(x=350,y=125)
#
# NameError: name 'budget_game_bot' is not defined
